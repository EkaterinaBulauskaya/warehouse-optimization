# %% [markdown]
# ### Расчет доступного места на складе
#
# Ноутбук использует функции из `calculate_warehouse_available_cap.py`, чтобы не дублировать бизнес-логику.
#
# Минимальный ноутбук: импорт, параметры, запуск расчета.

# %%
from calculate_warehouse_available_cap import run_pipeline

# %%
# Параметры запуска в ноутбуке:
# 1) warehouse_capacity (int) — общая вместимость склада.
# 2) file_date (str, формат YYYY-MM-DD) — дата в именах CSV-файлов.
warehouse_capacity = 150000
file_date = "2025-12-31"

available_space = run_pipeline(warehouse_capacity, file_date)
available_space
# Out:
# Calculation started. Please, wait...
#              Day   Space
# 0     12/31/2025   30671
# 1     01/01/2026   31707
# 2     01/02/2026   32745
# 3     01/03/2026   33784
# 4     01/04/2026   34823
# ...          ...     ...
# 1092  12/27/2028  120672
# 1093  12/28/2028  120672
# 1094  12/29/2028  120672
# 1095  12/30/2028  120672
# 1096  12/31/2028  120672
#
# [1097 rows x 2 columns]
